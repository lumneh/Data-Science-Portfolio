# %%
#Import all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %% [markdown]
# ## Data Understanding

# %%
transaction1 = pd.read_csv("dataset/cf1_delhi_transaction_data.csv")
transaction1.head()
# Out:
#    Unnamed: 0    chit    chit_id  p_recno  aucn_no   aucn_date  inst_due  \
# 0           0  AB-002  AB-002-01     8381        1  1999-03-01    2400.0
# 1           1  AB-002  AB-002-01     8381        2  1999-03-16    2400.0
# 2           2  AB-002  AB-002-01     8381        3  1999-04-01    2400.0
# 3           3  AB-002  AB-002-01     8381        4  1999-04-16    2400.0
# 4           4  AB-002  AB-002-01     8381        5  1999-05-01    2400.0
#
#    inst_paid  inst_spread  total_inst_due  ...  default  monthly_income  sex  \
# 0     4000.0       2400.0          2400.0  ...        0             NaN    M
# 1     2600.0       2400.0          4800.0  ...        0             NaN    M
# 2     1000.0       2400.0          7200.0  ...        0             NaN    M
# 3     1000.0       1400.0          9600.0  ...        0             NaN    M
# 4     3000.0       3000.0         12000.0  ...        0             NaN    M
#
# ...

# %%
transaction1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294900 entries, 0 to 294899
# Data columns (total 58 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            294900 non-null  int64
#  1   chit                  294900 non-null  object
#  2   chit_id               294900 non-null  object
#  3   p_recno               294900 non-null  int64
#  4   aucn_no               294900 non-null  int64
#  5   aucn_date             294900 non-null  object
#  6   inst_due              294900 non-null  float64
#  7   inst_paid             294900 non-null  float64
#  8   inst_spread           294900 non-null  float64
#  9   total_inst_due        294900 non-null  float64
#  10  total_inst_paid       294900 non-null  float64
#  11  div_due               294900 non-null  float64
#  12  div_paid              294900 non-null  float64
#  13  total_div_due         294900 non-null  float64
# ...

# %%
transaction1.shape
# Out:
# (294900, 58)

# %%
transaction1.drop_duplicates()
transaction1.shape
# Out:
# (294900, 58)

# %%
transaction1.describe()
# Out:
#           Unnamed: 0        p_recno        aucn_no       inst_due  \
# count  294900.000000  294900.000000  294900.000000  294900.000000
# mean   147449.500000    8420.084452      19.972703    2562.467107
# std     85130.441529    6197.400168      12.296989    3276.727157
# min         0.000000       1.000000       1.000000     375.000000
# 25%     73724.750000    3270.000000      10.000000     920.000000
# 50%    147449.500000    7528.000000      19.000000    1819.000000
# 75%    221174.250000   14002.000000      29.000000    2500.000000
# max    294899.000000   22065.000000      50.000000   25000.000000
#
#            inst_paid    inst_spread  total_inst_due  total_inst_paid  \
# count  294900.000000  294900.000000   294900.000000    294900.000000
# mean     2562.467107    2562.467107    44702.820624     44146.229262
# std      4779.593212    4583.069973    65646.912751     65160.659145
# min         0.000000       0.000000      500.000000         0.000000
# ...

# %% [markdown]
# ### Demographics

# %%
#Age Distribution
plt.figure(figsize=(5,5))
sns.set_style('whitegrid')
sns.distplot(transaction1['age'], kde=False, bins=10, color='r')
plt.title("Age Distribution")
plt.ylabel("No. of Members")
plt.show()
plt.savefig("agedistribution.png")
# Out:
# C:\Users\Lum-neh Angela\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Gender Distribution
plt.figure(figsize=(5,5))
sns_plot =sns.countplot(x="sex",data=transaction1)
plt.title('Gender distribution')
plt.savefig("Genderdistribution.png")

# %%
transaction1['sex'].value_counts()
# Out:
# M    192600
# F     95080
# Name: sex, dtype: int64

# %%
#Gender Distribution
plt.figure(figsize=(5,5))
sns_plot =sns.countplot(x="occupation",data=transaction1)
plt.title('Occupation distribution')
plt.savefig("Occupationdistribution.png")

# %%
transaction1['occupation'].value_counts()
# Out:
# PS    135775
# B      47510
# HW     23790
# GS     18865
# R      17225
# SE     15635
# P       4650
# BS        90
# 74        30
# SP        30
# OS        25
# SG        25
# Name: occupation, dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.set_style('whitegrid')
sns.distplot(transaction1['monthly_income'], kde=False, bins=10, color='r')
plt.title("Income Distribution")
plt.ylabel("No. of Members")
plt.show()
plt.savefig("incomedistribution.png")
# Out:
# C:\Users\Lum-neh Angela\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
transaction1[transaction1['monthly_income'] < 50000].count()
# Out:
# Unnamed: 0              203895
# chit                    203895
# chit_id                 203895
# p_recno                 203895
# aucn_no                 203895
# aucn_date               203895
# inst_due                203895
# inst_paid               203895
# inst_spread             203895
# total_inst_due          203895
# total_inst_paid         203895
# div_due                 203895
# div_paid                203895
# total_div_due           203895
# total_div_paid          203895
# participation           203895
# all_bids                203893
# win_loss                203895
# win_bid_amt             203895
# prized_amt              203895
# chit_value              203895
# start_date              203895
# monthly_contribution    203895
# duration                203895
# month                   203895
# tot_memb                203895
# fman_tkt                203895
# bylaw_no                203895
# penalty                 203895
# postage_cost            203895
# ...

# %% [markdown]
# #### Repayment Behavior

# %%
#Loan amount borrowed by members
plt.figure(figsize=(15,5))
sns_plot =sns.countplot(x="chit_value",data=transaction1)
plt.title('Loan Amount')
plt.savefig("Loanamount.png")

# %%
transaction1['chit_value'].min()
# Out:
# 15000.0

# %%
transaction1['chit_value'].max()
# Out:
# 1000000.0

# %%
transaction1[transaction1['chit_value'] == 50000].count()
# Out:
# Unnamed: 0              100000
# chit                    100000
# chit_id                 100000
# p_recno                 100000
# aucn_no                 100000
# aucn_date               100000
# inst_due                100000
# inst_paid               100000
# inst_spread             100000
# total_inst_due          100000
# total_inst_paid         100000
# div_due                 100000
# div_paid                100000
# total_div_due           100000
# total_div_paid          100000
# participation           100000
# all_bids                100000
# win_loss                100000
# win_bid_amt             100000
# prized_amt              100000
# chit_value              100000
# start_date              100000
# monthly_contribution    100000
# duration                100000
# month                   100000
# tot_memb                100000
# fman_tkt                100000
# bylaw_no                100000
# penalty                 100000
# postage_cost            100000
# ...

# %%
#Default on Monthly contributions
plt.figure(figsize=(5,5))
sns_plot =sns.countplot(x="default",data=transaction1)
plt.title('Default on Monthly Contributions')
plt.savefig("defaultMonthly.png")

# %%
transaction1['default'].value_counts()/transaction1['default'].count()
# Out:
# 0    0.961587
# 1    0.038413
# Name: default, dtype: float64

# %%
#Default on Monthly contributions
plt.figure(figsize=(5,5))
sns_plot =sns.countplot(x="default_90",data=transaction1)
plt.title('Default on Loan')
plt.savefig("loandefault.png")

# %%
transaction1['default_90'].value_counts()/transaction1['default_90'].count()
# Out:
# 0.0    0.975144
# 1.0    0.024856
# Name: default_90, dtype: float64

# %%
#Identifying missing values
transaction1.isnull().sum()
# Out:
# Unnamed: 0                   0
# chit                         0
# chit_id                      0
# p_recno                      0
# aucn_no                      0
# aucn_date                    0
# inst_due                     0
# inst_paid                    0
# inst_spread                  0
# total_inst_due               0
# total_inst_paid              0
# div_due                      0
# div_paid                     0
# total_div_due                0
# total_div_paid               0
# participation                0
# all_bids                     2
# win_loss                     0
# win_bid_amt                  0
# prized_amt                   0
# chit_value                   0
# start_date                   0
# monthly_contribution         0
# duration                     0
# month                        0
# tot_memb                     0
# fman_tkt                     0
# bylaw_no                     0
# penalty                      0
# postage_cost                 0
# ...

# %%
# finding outliers
plt.figure(figsize=(15,5))
sns.boxplot(x=transaction1['chit_value'])
plt.show()
plt.savefig("OutlierLoanamount.png")

# %%
# finding outliers
plt.figure(figsize=(15,5))
sns.boxplot(x=transaction1['monthly_income'])
plt.show()
plt.savefig("Outliermonthlyincome.png")

# %%
# Plot distributions...
#transaction1.hist(figsize = (35,35))

# %%
# loop through all non-numerical variables and count each unique value, and plot...
# for feature in transaction1.dtypes[transaction1.dtypes == 'object'].index:
#     sns.countplot(x=feature, data=transaction1, order = transaction1[feature].value_counts().index)
#     plt.show()

# %% [markdown]
# ## Data Preparation

# %%
transaction1.shape
# Out:
# (294900, 58)

# %%
trans = transaction1.drop(["lottery", "bid_type"], axis=1)
trans.head()
# Out:
#    Unnamed: 0    chit    chit_id  p_recno  aucn_no   aucn_date  inst_due  \
# 0           0  AB-002  AB-002-01     8381        1  1999-03-01    2400.0
# 1           1  AB-002  AB-002-01     8381        2  1999-03-16    2400.0
# 2           2  AB-002  AB-002-01     8381        3  1999-04-01    2400.0
# 3           3  AB-002  AB-002-01     8381        4  1999-04-16    2400.0
# 4           4  AB-002  AB-002-01     8381        5  1999-05-01    2400.0
#
#    inst_paid  inst_spread  total_inst_due  ...  irr_payment  late_payment  \
# 0     4000.0       2400.0          2400.0  ...            1             0
# 1     2600.0       2400.0          4800.0  ...            1             0
# 2     1000.0       2400.0          7200.0  ...            0             0
# 3     1000.0       1400.0          9600.0  ...            1             1
# 4     3000.0       3000.0         12000.0  ...            1             1
#
#    default  monthly_income  sex   age  occupation  before_after  all_trans  \
# ...

# %%
transaction = trans.dropna()
transaction.shape
# Out:
# (164422, 56)

# %%
transaction = transaction.reset_index(drop=True)

# %%
transaction.head()
# Out:
#    Unnamed: 0    chit    chit_id  p_recno  aucn_no   aucn_date  inst_due  \
# 0         210  AB-002  AB-002-08     4164        1  1999-03-01    2400.0
# 1         211  AB-002  AB-002-08     4164        2  1999-03-16    2400.0
# 2         212  AB-002  AB-002-08     4164        3  1999-04-01    2400.0
# 3         213  AB-002  AB-002-08     4164        4  1999-04-16    2400.0
# 4         214  AB-002  AB-002-08     4164        5  1999-05-01    2400.0
#
#    inst_paid  inst_spread  total_inst_due  ...  irr_payment  late_payment  \
# 0     1400.0       1400.0          2400.0  ...            1             1
# 1     2700.0       2700.0          4800.0  ...            1             1
# 2     2900.0       2900.0          7200.0  ...            1             1
# 3     1600.0       1600.0          9600.0  ...            1             1
# 4     2400.0       2400.0         12000.0  ...            1             1
#
#    default  monthly_income  sex   age  occupation  before_after  all_trans  \
# ...

# %%
# Split the data into training and test set in the ratio 70:30
transac_copy = transaction.copy()
transac_train = transac_copy.sample(frac=0.70, random_state=0)
transac_test = transac_copy.drop(transac_train.index)

# %%
transac_test.shape
# Out:
# (49327, 56)

# %%
transac_train.shape
# Out:
# (115095, 56)

# %%
transac_test.head()
# Out:
#     Unnamed: 0    chit    chit_id  p_recno  aucn_no   aucn_date  inst_due  \
# 2          212  AB-002  AB-002-08     4164        3  1999-04-01    2400.0
# 5          215  AB-002  AB-002-08     4164        6  1999-05-17    2400.0
# 10         220  AB-002  AB-002-08     4164       11  1999-08-02    2600.0
# 13         224  AB-002  AB-002-08     4164       15  1999-10-01    2730.0
# 21         232  AB-002  AB-002-08     4164       23  2000-02-01    2916.0
#
#     inst_paid  inst_spread  total_inst_due  ...  irr_payment  late_payment  \
# 2      2900.0       2900.0          7200.0  ...            1             1
# 5      2400.0       2400.0         14400.0  ...            1             1
# 10     2900.0       2900.0         27000.0  ...            1             1
# 13     2299.0       2299.0         37785.0  ...            1             1
# 21      600.0       1200.0         60369.0  ...            1             1
#
# ...

# %%
transac_train = transac_train.drop(["Unnamed: 0", "chit", "chit_id", "p_recno"], axis=1)
transac_train.head()
# Out:
#         aucn_no   aucn_date  inst_due  inst_paid  inst_spread  total_inst_due  \
# 66200         7  2005-08-20     750.0      750.0        750.0         5500.00
# 103884       25  2007-08-18     990.0      990.0        990.0        22776.00
# 157914       36  2008-02-23    4965.0     4950.0       4965.0       163538.50
# 38771        26  2000-07-15     849.5      820.0        849.5        19989.00
# 6271         30  2002-08-24    1470.0     1449.5       1470.0        38167.25
#
#         total_inst_paid  div_due  div_paid  total_div_due  ...  irr_payment  \
# 66200           5750.00    250.0     250.0        1500.00  ...            0
# 103884         22786.00     10.0      10.0        2224.00  ...            0
# 157914        163573.50     35.0      35.0       16461.50  ...            0
# 38771          20142.00    150.5     150.5        6011.00  ...            0
# 6271           38197.25     30.0      30.0        6832.75  ...            1
#
# ...

# %%
transac_train['bylaw_no']
# Out:
# 66200        F2/17/842/04-05
# 103884        F2/17/48/05-06
# 157914       F2/17/1301/0405
# 38771        F2/17/419/98-99
# 6271      F2/17/1417/99-2000
#                  ...
# 83243        F2/17/953/05-06
# 76986        F2/17/200/01-02
# 62577        F2/17/581/03-04
# 96335        F2/17/1154/2000
# 139631       F2/17/1325/03-4
# Name: bylaw_no, Length: 115095, dtype: object

# %%
transac_train = transac_train.drop(["aucn_no", "bylaw_no"], axis=1)
transac_train.head()
# Out:
#          aucn_date  inst_due  inst_paid  inst_spread  total_inst_due  \
# 66200   2005-08-20     750.0      750.0        750.0         5500.00
# 103884  2007-08-18     990.0      990.0        990.0        22776.00
# 157914  2008-02-23    4965.0     4950.0       4965.0       163538.50
# 38771   2000-07-15     849.5      820.0        849.5        19989.00
# 6271    2002-08-24    1470.0     1449.5       1470.0        38167.25
#
#         total_inst_paid  div_due  div_paid  total_div_due  total_div_paid  \
# 66200           5750.00    250.0     250.0        1500.00         1500.00
# 103884         22786.00     10.0      10.0        2224.00         2224.00
# 157914        163573.50     35.0      35.0       16461.50        16461.50
# 38771          20142.00    150.5     150.5        6011.00         6011.00
# 6271           38197.25     30.0      30.0        6832.75         6832.75
#
#         ...  irr_payment  late_payment  default  monthly_income  sex   age  \
# ...

# %%
transac_train = transac_train.drop(["aucn_date", "start_date", "last_trans_date", "last_payment_date"], axis=1)
transac_train.head()
# Out:
#         inst_due  inst_paid  inst_spread  total_inst_due  total_inst_paid  \
# 66200      750.0      750.0        750.0         5500.00          5750.00
# 103884     990.0      990.0        990.0        22776.00         22786.00
# 157914    4965.0     4950.0       4965.0       163538.50        163573.50
# 38771      849.5      820.0        849.5        19989.00         20142.00
# 6271      1470.0     1449.5       1470.0        38167.25         38197.25
#
#         div_due  div_paid  total_div_due  total_div_paid  participation  ...  \
# 66200     250.0     250.0        1500.00         1500.00            0.0  ...
# 103884     10.0      10.0        2224.00         2224.00            0.0  ...
# 157914     35.0      35.0       16461.50        16461.50            0.0  ...
# 38771     150.5     150.5        6011.00         6011.00            0.0  ...
# 6271       30.0      30.0        6832.75         6832.75            0.0  ...
#
# ...

# %% [markdown]
# ### Handling Outliers

# %%
# delete members with monthly income above 50,000
transac_train = transac_train[transac_train['monthly_income']<=50000]
transac_train.shape
# Out:
# (114412, 46)

# %%
# delete loans with values more than 200,000
transac_train = transac_train[transac_train['chit_value']<=200000]
transac_train.shape
# Out:
# (112013, 46)

# %% [markdown]
# ### Balance unbalance dataset

# %%
#percentage distribution of target
transac_train["default_90"].value_counts()/transac_train["default_90"].count()
# Out:
# 0.0    0.998839
# 1.0    0.001161
# Name: default_90, dtype: float64

# %%
transac_train["default_90"].value_counts()
# Out:
# 0.0    111883
# 1.0       130
# Name: default_90, dtype: int64

# %%
majority = transac_train[transac_train["default_90"] == 0]
majority.shape
# Out:
# (111883, 46)

# %%
# Separate majority and minority classes
not_defaulted = transac_train[transac_train["default_90"] == 0]
defaulted = transac_train[transac_train["default_90"] == 1]

# %%
# upsampling the minority positive class
from sklearn.utils import resample
defaulted_upsampled = resample(defaulted, replace=True, n_samples=majority.shape[0], random_state=0)

# %%
#merge the upsampled defaulted class and not defaulted class
upsampled_trainingdata= pd.concat([not_defaulted, defaulted_upsampled])

# %%
upsampled_trainingdata.head()
# Out:
#         inst_due  inst_paid  inst_spread  total_inst_due  total_inst_paid  \
# 66200      750.0      750.0        750.0         5500.00          5750.00
# 103884     990.0      990.0        990.0        22776.00         22786.00
# 157914    4965.0     4950.0       4965.0       163538.50        163573.50
# 38771      849.5      820.0        849.5        19989.00         20142.00
# 6271      1470.0     1449.5       1470.0        38167.25         38197.25
#
#         div_due  div_paid  total_div_due  total_div_paid  participation  ...  \
# 66200     250.0     250.0        1500.00         1500.00            0.0  ...
# 103884     10.0      10.0        2224.00         2224.00            0.0  ...
# 157914     35.0      35.0       16461.50        16461.50            0.0  ...
# 38771     150.5     150.5        6011.00         6011.00            0.0  ...
# 6271       30.0      30.0        6832.75         6832.75            0.0  ...
#
# ...

# %%
upsampled_trainingdata.shape
# Out:
# (223766, 46)

# %%
#percentage distribution of target
upsampled_trainingdata["default_90"].value_counts()/upsampled_trainingdata["default_90"].count()
# Out:
# 1.0    0.5
# 0.0    0.5
# Name: default_90, dtype: float64

# %%
sns_plot =sns.countplot(x="default_90",data=upsampled_trainingdata)
plt.savefig("balanceddata.png")

# %% [markdown]
# ### Encoding Categorical Variables

# %%
#Encoding of categorical variables using one-hot encoding
upsampled_trainingdata = pd.get_dummies(upsampled_trainingdata, drop_first=True)

# %%
upsampled_trainingdata
# Out:
#         inst_due    inst_paid  inst_spread  total_inst_due  total_inst_paid  \
# 66200      750.0   750.000000        750.0         5500.00          5750.00
# 103884     990.0   990.000000        990.0        22776.00         22786.00
# 157914    4965.0  4950.000000       4965.0       163538.50        163573.50
# 38771      849.5   820.000000        849.5        19989.00         20142.00
# 6271      1470.0  1449.500000       1470.0        38167.25         38197.25
# ...          ...          ...          ...             ...              ...
# 34123      999.0  4730.000000       4730.0        40597.30         36685.00
# 14888      904.0     0.000000          0.0        31001.20         27567.70
# 27975     1000.0  1000.000000       1000.0        41714.30         38696.30
# 14892      970.0  1893.300049       1893.3        34794.50         30391.00
# 15426      955.5     0.000000          0.0        33824.50         28527.70
#
# ...

# %%
upsampled_trainingdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 223766 entries, 66200 to 15426
# Data columns (total 54 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   inst_due              223766 non-null  float64
#  1   inst_paid             223766 non-null  float64
#  2   inst_spread           223766 non-null  float64
#  3   total_inst_due        223766 non-null  float64
#  4   total_inst_paid       223766 non-null  float64
#  5   div_due               223766 non-null  float64
#  6   div_paid              223766 non-null  float64
#  7   total_div_due         223766 non-null  float64
#  8   total_div_paid        223766 non-null  float64
#  9   participation         223766 non-null  float64
#  10  all_bids              223766 non-null  float64
#  11  win_loss              223766 non-null  int64
#  12  win_bid_amt           223766 non-null  int64
#  13  prized_amt            223766 non-null  float64
# ...

# %%
# extract the target variable
y_train = upsampled_trainingdata['default_90'] 
y_train.head()
# Out:
# 66200     0.0
# 103884    0.0
# 157914    0.0
# 38771     0.0
# 6271      0.0
# Name: default_90, dtype: float64

# %%
y_train.value_counts()
# Out:
# 1.0    111883
# 0.0    111883
# Name: default_90, dtype: int64

# %%
# extract the features
X_train = upsampled_trainingdata.loc[:, upsampled_trainingdata.columns != "default_90"]
X_train.head()
# Out:
#         inst_due  inst_paid  inst_spread  total_inst_due  total_inst_paid  \
# 66200      750.0      750.0        750.0         5500.00          5750.00
# 103884     990.0      990.0        990.0        22776.00         22786.00
# 157914    4965.0     4950.0       4965.0       163538.50        163573.50
# 38771      849.5      820.0        849.5        19989.00         20142.00
# 6271      1470.0     1449.5       1470.0        38167.25         38197.25
#
#         div_due  div_paid  total_div_due  total_div_paid  participation  ...  \
# 66200     250.0     250.0        1500.00         1500.00            0.0  ...
# 103884     10.0      10.0        2224.00         2224.00            0.0  ...
# 157914     35.0      35.0       16461.50        16461.50            0.0  ...
# 38771     150.5     150.5        6011.00         6011.00            0.0  ...
# 6271       30.0      30.0        6832.75         6832.75            0.0  ...
#
# ...

# %% [markdown]
# ### Normalise the X_train

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_train
# Out:
# array([[-0.97265491, -0.4727721 , -0.47946856, ..., -0.23965664,
#         -0.24286138, -0.00791007],
#        [-0.74152775, -0.35858244, -0.36113689, ..., -0.23965664,
#         -0.24286138, -0.00791007],
#        [ 3.08651581,  1.52554701,  1.59873136, ..., -0.23965664,
#         -0.24286138, -0.00791007],
#        ...,
#        [-0.73189745, -0.35382454, -0.3562064 , ..., -0.23965664,
#         -0.24286138, -0.00791007],
#        [-0.76078835,  0.07119893,  0.08423392, ..., -0.23965664,
#         -0.24286138, -0.00791007],
#        [-0.77475228, -0.8296148 , -0.84925502, ..., -0.23965664,
#         -0.24286138, -0.00791007]])

# %% [markdown]
# ### Modelling

# %%
# Training the randomforest base classifier
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100, max_features="auto", random_state=0)  
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
# Training the ADAboost base classifier
from sklearn.ensemble import AdaBoostClassifier
abc = AdaBoostClassifier(n_estimators=100)
abc.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=100)

# %%
# Training the gradient boosting base classifier
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(n_estimators=100)
gbc.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
# Training the XG boosting base classifier
from xgboost import XGBClassifier
xgbc = XGBClassifier(n_estimators=100, verbosity=0)
xgbc.fit(X_train, y_train)
# Out:
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [03:08:32] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
# ...

# %% [markdown]
# ### Evaluation

# %%
transac_test = transac_test.drop(["Unnamed: 0","chit", "chit_id", "p_recno", "aucn_no", "aucn_date", "bylaw_no", 
                                  "start_date", "last_trans_date", "last_payment_date"], axis=1)
transac_test.head()
# Out:
#     inst_due  inst_paid  inst_spread  total_inst_due  total_inst_paid  \
# 2     2400.0     2900.0       2900.0          7200.0           7000.0
# 5     2400.0     2400.0       2400.0         14400.0          13400.0
# 10    2600.0     2900.0       2900.0         27000.0          26200.0
# 13    2730.0     2299.0       2299.0         37785.0          36455.0
# 21    2916.0      600.0       1200.0         60369.0          58653.0
#
#     div_due  div_paid  total_div_due  total_div_paid  participation  ...  \
# 2     600.0     600.0         1800.0          1800.0            0.0  ...
# 5     600.0     600.0         3600.0          3600.0            0.0  ...
# 10    400.0     400.0         6000.0          6000.0            0.0  ...
# 13    270.0     270.0         7215.0          7215.0            0.0  ...
# 21     84.0      84.0         8631.0          8631.0            0.0  ...
#
#     irr_payment  late_payment  default  monthly_income  sex   age  occupation  \
# ...

# %%
transac_test = transac_test[transac_test['monthly_income']<=50000]
transac_test.shape
# Out:
# (49061, 46)

# %%
transac_test = transac_test[transac_test['chit_value']<=200000]
transac_test.shape
# Out:
# (48037, 46)

# %%
transac_test = pd.get_dummies(transac_test, drop_first=True)

# %%
X_test = transac_test.iloc[:, :-1]
y_test = transac_test["default_90"]
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# #### RandomForest Evaluation

# %%
y_pred = rfc.predict(X_test)
y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay, accuracy_score
cm = confusion_matrix(y_test, y_pred, labels=rfc.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=rfc.classes_)
sns.set_style('white')
disp.plot()
disp.figure_.suptitle("Confusion Matrix for RandomForest")
plt.show()
plt.savefig("rfc.png")

# %%
from sklearn import metrics
print("F1-score:", metrics.f1_score(y_test, y_pred))
print("Accuracy Score:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred))
print("Recall:", metrics.recall_score(y_test, y_pred))
# Out:
# F1-score: 0.591715976331361
# Accuracy Score: 0.998563607219435
# Precision: 0.46296296296296297
# Recall: 0.819672131147541

# %%
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve of RandomForest')
plt.legend(loc=4)
plt.show()
plt.savefig("rfc_auc.png")

# %% [markdown]
# #### AdaBoost Evalutaion

# %%
y_pred = abc.predict(X_test)
y_pred
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
cm = confusion_matrix(y_test, y_pred, labels=abc.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=abc.classes_)
sns.set_style('white')
disp.plot()
disp.figure_.suptitle("Confusion Matrix")
plt.show()
plt.savefig("abc.png")

# %%
print("F1-score:", metrics.f1_score(y_test, y_pred))
print("ROC curve:", metrics.roc_curve(y_test, y_pred))
print("Accuracy Score:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred))
print("Recall:", metrics.recall_score(y_test, y_pred))
# Out:
# F1-score: 0.06967447173043975
# ROC curve: (array([0.        , 0.03395448, 1.        ]), array([0., 1., 1.]), array([2., 1., 0.]))
# Accuracy Score: 0.9660886400066615
# Precision: 0.03609467455621302
# Recall: 1.0

# %%
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve')
plt.legend(loc=4)
plt.show()
plt.savefig("abc_auc.png")

# %% [markdown]
# #### GradientBoost Evaluation

# %%
y_pred = gbc.predict(X_test)
y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
cm = confusion_matrix(y_test, y_pred, labels=gbc.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=gbc.classes_)
sns.set_style('white')
disp.plot()
disp.figure_.suptitle("Confusion Matrix")
plt.show()
plt.savefig("gbc.png")

# %%
print("F1-score:", metrics.f1_score(y_test, y_pred))
print("ROC curve:", metrics.roc_curve(y_test, y_pred))
print("Accuracy Score:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred))
print("Recall:", metrics.recall_score(y_test, y_pred))
# Out:
# F1-score: 0.5773195876288659
# ROC curve: (array([0.        , 0.00160497, 1.        ]), array([0.        , 0.91803279, 1.        ]), array([2., 1., 0.]))
# Accuracy Score: 0.9982929824926619
# Precision: 0.42105263157894735
# Recall: 0.9180327868852459

# %%
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve')
plt.legend(loc=4)
plt.show()
plt.savefig("gbc_auc.png")

# %% [markdown]
# #### XGBoost Evaluation

# %%
y_pred = xgbc.predict(X_test)
y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
cm = confusion_matrix(y_test, y_pred, labels=xgbc.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=xgbc.classes_)
disp.plot()
disp.figure_.suptitle("Confusion Matrix")
plt.show()
# plt.savefig("xgbc.png")

# %%
print("F1-score:", metrics.f1_score(y_test, y_pred))
print("ROC curve:", metrics.roc_curve(y_test, y_pred))
print("Accuracy Score:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred))
print("Recall:", metrics.recall_score(y_test, y_pred))
# Out:
# F1-score: 0.4692307692307693
# ROC curve: (array([0.        , 0.00287644, 1.        ]), array([0., 1., 1.]), array([2., 1., 0.]))
# Accuracy Score: 0.9971272144388701
# Precision: 0.3065326633165829
# Recall: 1.0

# %%
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve')
plt.legend(loc=4)
plt.show()
# plt.savefig("xgbc_auc.png")

# %% [markdown]
# #### Feature Selection

# %%
#A mutation operator which looks at all of the booleans that represent the features in our data, and randomly flips one - if 
#it was previously included, it is now excluded, and if it was previously excluded, it is now included.

import random
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

def mutationOperator(features):
    feat_to_flip = random.choice(range(0,len(features))) 
    
    if(features[feat_to_flip] ==True):
        features[feat_to_flip] = False
    else:
        features[feat_to_flip] = True
    
    return features

# %%
#objective function for cross validation
def objective(X_train, y_train, model, features_to_include):
    # Determine the splits
    splits = StratifiedKFold(n_splits=5, shuffle=True)
    # Test Model
    auc = np.mean(cross_val_score(model, X_train[:, features_to_include], y_train, cv=splits, scoring='roc_auc'))
    return auc

# %%
def localSearchFeatureSelection(X_train, y_train, model, current_x, number_of_iterations):
    current_fitness = objective(X_train, y_train, model, current_x)

    for i in range(0,number_of_iterations):
        # mutate the current solution
        new_x = mutationOperator(current_x.copy())
        # evaluate it
        new_fitness = objective(X_train, y_train, model, new_x)
        
        if(new_fitness > current_fitness):
            current_x = new_x
            current_fitness = new_fitness

        print("Iteration",i, ": Selected Features:", str(sum(current_x)),"/",str(X_train.shape[1]),"Fitness:", current_fitness)
    return current_x

# %%
# using the best model
model = XGBClassifier(n_estimators=100, use_label_encoder=False, verbosity=0)
# every feature is set to True in that it should be included
all_features = [True] * (X_train.shape[1])
# We can test the full feature subset like this
print("The AUC from cross validation on the full training data is", objective(X_train, y_train, model, all_features))
# Out:
# The AUC from cross validation on the full training data is 0.999999857008804

# %%
number_of_iterations = 50
best_subset = localSearchFeatureSelection(X_train, y_train, model, all_features, number_of_iterations)
# Out:
# Iteration 0 : Selected Features: 52 / 53 Fitness: 0.9999999257084848
# Iteration 1 : Selected Features: 52 / 53 Fitness: 0.9999999257084848
# Iteration 2 : Selected Features: 52 / 53 Fitness: 0.9999999257084848
# Iteration 3 : Selected Features: 51 / 53 Fitness: 0.9999999261045993
# Iteration 4 : Selected Features: 51 / 53 Fitness: 0.9999999261045993
# Iteration 5 : Selected Features: 51 / 53 Fitness: 0.9999999261045993
# Iteration 6 : Selected Features: 51 / 53 Fitness: 0.9999999261045993
# Iteration 7 : Selected Features: 51 / 53 Fitness: 0.9999999261045993
# Iteration 8 : Selected Features: 51 / 53 Fitness: 0.9999999261045993
# Iteration 9 : Selected Features: 51 / 53 Fitness: 0.9999999261045993
# Iteration 10 : Selected Features: 51 / 53 Fitness: 0.9999999261045993
# Iteration 11 : Selected Features: 51 / 53 Fitness: 0.9999999261045993
# Iteration 12 : Selected Features: 50 / 53 Fitness: 1.0
# Iteration 13 : Selected Features: 50 / 53 Fitness: 1.0
# ...

# %%
import shap

# %%
feat_names = upsampled_trainingdata.loc[:, upsampled_trainingdata.columns != "default_90"].columns
feat_names
# Out:
# Index(['inst_due', 'inst_paid', 'inst_spread', 'total_inst_due',
#        'total_inst_paid', 'div_due', 'div_paid', 'total_div_due',
#        'total_div_paid', 'participation', 'all_bids', 'win_loss',
#        'win_bid_amt', 'prized_amt', 'chit_value', 'monthly_contribution',
#        'duration', 'month', 'tot_memb', 'fman_tkt', 'penalty', 'postage_cost',
#        'nj_stamp_cost', 'other_cost', 'by_chq', 'by_cash', 'by_other',
#        'bounced_chq', 'missed_inst', 'missed_div', 'diff_inst', 'no_trans',
#        'total_trans', 'multi_payment', 'early_payment', 'part_payment',
#        'irr_payment', 'late_payment', 'default', 'monthly_income', 'age',
#        'before_after', 'all_trans', 'sex_M', 'occupation_BS', 'occupation_GS',
#        'occupation_HW', 'occupation_OS', 'occupation_P', 'occupation_PS',
#        'occupation_R', 'occupation_SE', 'occupation_SG'],
#       dtype='object')

# %%
X_trainp =pd.DataFrame(X_train, columns=feat_names)
X_trainp.head()
# Out:
#    inst_due  inst_paid  inst_spread  total_inst_due  total_inst_paid  \
# 0 -0.972655  -0.472772    -0.479469       -1.127328        -1.035604
# 1 -0.741528  -0.358582    -0.361137       -0.494874        -0.385354
# 2  3.086516   1.525547     1.598731        4.658273         4.988392
# 3 -0.876833  -0.439467    -0.430410       -0.596903        -0.486273
# 4 -0.279273  -0.139957    -0.124474        0.068581         0.202881
#
#     div_due  div_paid  total_div_due  total_div_paid  participation  ...  \
# 0  0.219975  0.159334      -1.307164       -1.294945      -0.428321  ...
# 1 -0.741051 -0.512923      -1.131012       -1.118856      -0.428321  ...
# 2 -0.640944 -0.442897       2.333028        2.343932      -0.428321  ...
# 3 -0.178451 -0.119372      -0.209620       -0.197797      -0.428321  ...
# 4 -0.660966 -0.456902      -0.009685        0.002066      -0.428321  ...
#
#       sex_M  occupation_BS  occupation_GS  occupation_HW  occupation_OS  \
# ...

# %%
X_testp =pd.DataFrame(X_test, columns=feat_names)
X_testp.head()
# Out:
#    inst_due  inst_paid  inst_spread  total_inst_due  total_inst_paid  \
# 0  0.552751   0.452605     0.504251       -0.827341        -0.841471
# 1  0.552751   0.195368     0.229849       -0.590465        -0.630780
# 2  0.723712   0.452605     0.504251       -0.175931        -0.209397
# 3  0.834836   0.143406     0.174420        0.178890         0.128203
# 4  0.993830  -0.730685    -0.428715        0.921892         0.858973
#
#     div_due  div_paid  total_div_due  total_div_paid  participation  ...  \
# 0  1.627989  1.710004      -0.883650       -0.879540      -0.377402  ...
# 1  1.627989  1.710004      -0.490280       -0.486053      -0.377402  ...
# 2  0.806769  0.885518       0.034213        0.038596      -0.377402  ...
# 3  0.272976  0.349602       0.299737        0.304199      -0.377402  ...
# 4 -0.490758 -0.417170       0.609188        0.613742      -0.377402  ...
#
#       sex_M  occupation_BS  occupation_GS  occupation_HW  occupation_OS  \
# ...

# %% [markdown]
# ### Global Explainability

# %%
model_xgb = model.fit(X_train, y_train)
explainer_xgb = shap.Explainer(model_xgb, X100)
shap_values = explainer_xgb(X_trainp)
# Out:
# 100%|===================| 223659/223766 [08:04<00:00]

# %% [markdown]
# #### Variable Importance Plot

# %%
# Variable Importance plot list the most significant variables in descending order
shap.summary_plot(shap_values, X_trainp, plot_type="bar")

# %%
#SHAP value summary plot plot showing positive and negative relationships of features with the default_90 (target)
shap.summary_plot(shap_values, X_trainp)

# %%
def sim_sum(shap, data):
    #import matplotlib as plt
    # Make a copy of the input data
    shap_v = pd.DataFrame(shap)
    features = data.columns
    shap_v.columns = features
    data_v = data.copy().reset_index().drop('index',axis=1)
    
    # Determine the correlation in order to plot with different colors
    corr_list = list()
    for i in features:
        b = np.corrcoef(shap_v[i],data_v[i])[1][0]
        corr_list.append(b)
    corr_df = pd.concat([pd.Series(features),pd.Series(corr_list)],axis=1).fillna(0)
    # Make a data frame. Column 1 is the feature, and Column 2 is the correlation coefficient
    corr_df.columns  = ['Variable','Corr']
    corr_df['Sign'] = np.where(corr_df['Corr']>0,'red','blue')
    
    # Plot it
    shap_abs = np.abs(shap_v)
    k=pd.DataFrame(shap_abs.mean()).reset_index()
    k.columns = ['Variable','SHAP_abs']
    k2 = k.merge(corr_df,left_on = 'Variable',right_on='Variable',how='inner')
    k2 = k2.sort_values(by='SHAP_abs',ascending = True)
    colorlist = k2['Sign']
    ax = k2.plot.barh(x='Variable',y='SHAP_abs',color = colorlist, figsize=(7,12),legend=False)
    ax.set_xlabel("SHAP Value (Red = Positive Impact)")

# %%
def ABS_SHAP(df_shap,df):
    #import matplotlib as plt
    # Make a copy of the input data
    shap_v = pd.DataFrame(df_shap)
    feature_list = df.columns
    shap_v.columns = feature_list
    df_v = df.copy().reset_index().drop('index',axis=1)
    
    # Determine the correlation in order to plot with different colors
    corr_list = list()
    for i in feature_list:
        b = np.corrcoef(shap_v[i],df_v[i])[1][0]
        corr_list.append(b)
    corr_df = pd.concat([pd.Series(feature_list),pd.Series(corr_list)],axis=1).fillna(0)
    # Make a data frame. Column 1 is the feature, and Column 2 is the correlation coefficient
    corr_df.columns  = ['Variable','Corr']
    corr_df['Sign'] = np.where(corr_df['Corr']>0,'red','blue')
    
    # Plot it
    shap_abs = np.abs(shap_v)
    k=pd.DataFrame(shap_abs.mean()).reset_index()
    k.columns = ['Variable','SHAP_abs']
    k2 = k.merge(corr_df,left_on = 'Variable',right_on='Variable',how='inner')
    k2 = k2.sort_values(by='SHAP_abs',ascending = True)
    colorlist = k2['Sign']
    ax = k2.plot.barh(x='Variable',y='SHAP_abs',color = colorlist, figsize=(5,6),legend=False)
    ax.set_xlabel("SHAP Value (Red = Positive Impact)")

# %%
ABS_SHAP(shap_values, X_trainp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-363-83c2a862b9b1> in <module>
# ----> 1 ABS_SHAP(shap_values, X_trainp)
#
# <ipython-input-362-3e3c001dfd38> in ABS_SHAP(df_shap, df)
#       2     #import matplotlib as plt
#       3     # Make a copy of the input data
# ----> 4     shap_v = pd.DataFrame(df_shap)
#       5     feature_list = df.columns
#       6     shap_v.columns = feature_list
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527         else:
#     528             if index is None or columns is None:
# --> 529                 raise ValueError("DataFrame constructor not properly called!")
#     530
#     531             if not dtype:
#
# ValueError: DataFrame constructor not properly called!

# %% [markdown]
# #### SHAP Dependence Plot

# %%
shap_values_p = explainer_xgb(X_train)
# Out:
# 100%|===================| 223338/223766 [07:52<00:00]

# %%
#Partial dependence plot showing the relationship betwwen the diff_inst feature and target
shap.dependence_plot('diff_inst', shap_values, X_trainp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-373-61f88203d44c> in <module>
#       1 #Partial dependence plot showing the relationship betwwen the diff_inst feature and target
# ----> 2 shap.dependence_plot('default', shap_values, X_trainp)
#
# ~\anaconda3\lib\site-packages\shap\plots\_scatter.py in dependence_legacy(ind, shap_values, features, feature_names, display_features, interaction_index, color, axis_color, cmap, dot_size, x_jitter, alpha, title, xmin, xmax, ax, show)
#     559     if not hasattr(ind, "__len__"):
#     560         if interaction_index == "auto":
# --> 561             interaction_index = approximate_interactions(ind, shap_values, features)[0]
#     562         interaction_index = convert_name(interaction_index, shap_values, feature_names)
#     563     categorical_interaction = False
#
# ...

# %%
#Partial dependence plot showing the relationship between the default feature and target
#shap.dependence_plot('default', shap_values, X_trainp)

# %%
#Partial dependence plot showing the relationship between the inst_due feature and target
# shap.dependence_plot('inst_due', shap_values, X_trainp)

# %%
shap.dependence_plot('diff_inst', shap_values_p, X_trainp)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide

# %%
shap.dependence_plot('default', shap_values_p, X_trainp)

# %%
shap.dependence_plot('inst_due', shap_values_p, X_trainp)

# %% [markdown]
# ### Local Interpretability

# %% [markdown]
# #### Individual SHAP Value Plot

# %%
# Get the predictions and put them with the test data.
X_output = X_testp.copy()
X_output.loc[:,'predict'] = model_xgb.predict(X_output)

# Randomly pick some observations
random_picks = np.arange(1,330,50) # Every 50 rows
S = X_output.iloc[random_picks]
S
# Out:
#      inst_due  inst_paid  inst_spread  total_inst_due  total_inst_paid  \
# 1    0.552751   0.195368     0.229849       -0.590465        -0.630780
# 51   0.552751   1.121421     1.217696       -0.827341        -0.834887
# 101  0.959638   1.430105     0.491080        0.688536         0.819962
# 151  0.552751   0.195368     0.229849       -0.748382        -0.736126
# 201  0.765597  -0.005277     0.366501       -0.168233         0.020553
# 251  1.035716   0.276140     0.316011        1.011675         0.947200
# 301 -0.537125  -0.460586    -0.469876       -0.570725        -0.565762
#
#       div_due  div_paid  total_div_due  total_div_paid  participation  ...  \
# 1    1.627989  1.710004      -0.490280       -0.486053      -0.377402  ...
# 51   1.627989  1.710004      -0.883650       -0.879540      -0.377402  ...
# 101 -0.326514 -0.252273       0.192435        0.196865      -0.377402  ...
# 151  1.627989  1.710004      -0.752527       -0.748378      -0.377402  ...
# ...

# %%
# Initialize your Jupyter notebook with initjs(), to avoid an error message.
shap.initjs()

# Write in a function
def shap_plot(j):
    explainerModel = shap.Explainer(model_xgb)
    shap_values_Model = explainerModel.shap_values(S)
    p = shap.force_plot(explainerModel.expected_value, shap_values_Model[j], S.iloc[[j]])
    return(p)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
shap_plot(0)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\shap\explainers\_tree.py in shap_values(self, X, y, tree_limit, approximate, check_additivity, from_call)
#     330                 try:
# --> 331                     phi = self.model.original_model.predict(
#     332                         X, ntree_limit=tree_limit, pred_contribs=True,
#
# ~\anaconda3\lib\site-packages\xgboost\core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features, training, iteration_range, strict_shape)
#    1912         dims = c_bst_ulong()
# -> 1913         _check_call(
#    1914             _LIB.XGBoosterPredictFromDMatrix(
#
# ~\anaconda3\lib\site-packages\xgboost\core.py in _check_call(ret)
#     217     if ret != 0:
# ...

# %% [markdown]
# #### Heatmap plot

# %%
shap_values_1000 = explainer(X_trainp[:1000])

# %%
shap.plots.heatmap(shap_values_1000)

# %% [markdown]
# #### Scatter Plots

# %%
shap.plots.scatter(shap_values[:,'diff_inst'], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,'default'], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,'inst_due'], color=shap_values)

# %% [markdown]
# #### Waterfall Plots

# %%
# For the 10th observation
shap.plots.waterfall(shap_values[10], max_display=20)

# %%
#For the 1000th observation
shap.plots.waterfall(shap_values[1000], max_display=20)

# %%
shap.plots.bar(shap_values[10], max_display=20)

# %%
shap.plots.bar(shap_values[1000], max_display=20)

# %% [markdown]
# #### Force Plots

# %%
explainer = shap.Explainer(model_xgb)
shap_values = explainer.shap_values(X_testp)
shap.initjs()
def observation(j):
    return(shap.force_plot(explainer.expected_value, shap_values[j,:], X_testp.iloc[j,:]))
observation(10)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
observation(1000)
# Out:
# <div id='iDQ2FC8QY0L02D99K50CE'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
observation(250)
# Out:
# <div id='iO1L8W2VYGJ9H40G6929U'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.initjs()
def observation(j):
    explainer = shap.Explainer(model_xgb)
    xgb_binary_shap_values = explainer.shap_values(X_trainp)
    return(shap.force_plot(explainer.expected_value, xgb_binary_shap_values[j,:], X_trainp.iloc[j,:], link='logit'))
observation(10)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
observation(1000)
# Out:
# <div id='i7D3UDQ88RN25GNZ65HFH'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
observation(250)
# Out:
# <div id='iPX1VN141QHKLYYNIPBLH'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...
